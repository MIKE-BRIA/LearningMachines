# %%
## List

lst = []
print(type(lst))
# Out:
# <class 'list'>

# %%
names = ['Alice', 'Bob', 'Charlie']
print(names)
# Out:
# ['Alice', 'Bob', 'Charlie']

# %%
## Accessing elements in a list

fruits = ['apple', 'banana', 'cherry', 'date', 'elderberry']

print(fruits[0])
# Out:
# apple

# %%
print(fruits[0:5])
# Out:
# ['apple', 'banana', 'cherry', 'date', 'elderberry']

# %%
print(fruits[-1:-3])
# Out:
# []

# %%
## Modifying a list

fruits[0] = 'avocado'
print(fruits)
# Out:
# ['avocado', 'banana', 'cherry', 'date', 'elderberry']
