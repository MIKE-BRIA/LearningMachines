# %% [markdown]
# ## Exception handling

# %% [markdown]
# ###### for handling errors and take corrective actions without stopping the execution of the program

# %%
## Exception try, except, block

a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 ## Exception try, except, block
# ----> 3 a=b
#
# NameError: name 'b' is not defined

# %%
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
try:
    result=10/0
except ZeroDivisionError as ex:
    print(ex)
    print('You cannot divide by zero bigboy')
# Out:
# division by zero
# You cannot divide by zero bigboy

# %%
try:
    result=10/2
    a=b
except ZeroDivisionError as ex:
    print(ex)
    print('You cannot divide by zero ')
except Exception as ex:
    print(ex)
    print('Main exception got caught')
# Out:
# name 'b' is not defined
# Main exception got caught

# %%
try:
    num = int(input('Enter a number: '))
    result = 10/num
except ValueError as ex:
    print(ex)
    print('Please enter a valid number')
except ZeroDivisionError as ex:
    print(ex)
    print('You cannot divide by zero')
except Exception as ex:
    print(ex)
    print('An unexpected error occurred')
# Out:
# invalid literal for int() with base 10: 'gfsd'
# Please enter a valid number

# %%
## try ,except,else block

try:
    num = int(input('Enter a number: '))
    result = 10/num
except ValueError as ex:
    print('enter a valid number')
except ZeroDivisionError as ex:
    print('You cannot divide by zero')
except Exception as ex:
    print(ex)
else:
    print('The result is', result)
# Out:
# The result is 0.4

# %%
## try, except, else, finally
## finally will always be executed regardless of whether an exception was raised or not

try:
    num = int(input('Enter a number: '))
    result = 10/num
except ValueError as ex:
    print('enter a valid number')
except ZeroDivisionError as ex:
    print('You cannot divide by zero')
except Exception as ex:
    print(ex)
else:
    print('The result is', result)
finally:
    print('Exception completed')
# Out:
# The result is 0.00998003992015968
# Exception completed

# %%
### file handling and exceptions handling

try:
    file = open('non_existent_file.txt', 'r')
    content=file.read()
    print(content)
except FileNotFoundError as ex:
    print('the file does not exist')
finally:
    if 'file' in locals() and not file.closed:
        file.close()
        print('file closed successfully')
# Out:
# the file does not exist
